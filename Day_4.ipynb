# %% [markdown]
# <a href="https://colab.research.google.com/github/pranav1845/Data_Science_Internship/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 4 of Data science in python

# Todays Topics: Flow control statements in python

# Yesterday recap : Tuple, Set, Dictionary

age = int(input("Enter your age: "))
REQUIRED_AGE = 18

if age >= REQUIRED_AGE:
  print("You are eligible !")
# Out:
# Enter your age: 21
# You are eligible !

# %%
print("hello world")

for latter in "Hello world!":
  print(latter)
